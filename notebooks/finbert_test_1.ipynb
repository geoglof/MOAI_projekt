# %%
from transformers import pipeline

finbert = pipeline("sentiment-analysis", model="ProsusAI/finbert")

headlines = [
    "Fed raises interest rates by 0.5%, markets tumble",
    "Apple reports record quarterly revenue, stock jumps 5%",
    "Unemployment remains steady at 3.7%",
    "Some stupid dog ate my shoe.",
    "S&P 500 closes at all-time high on strong earnings season",
]

for h in headlines:
    result = finbert(h)
    print(f"{result[0]['label']:>10} ({result[0]['score']:.2f})  |  {h}")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# BertForSequenceClassification LOAD REPORT from: ProsusAI/finbert
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# bert.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#    neutral (0.61)  |  Fed raises interest rates by 0.5%, markets tumble
#   positive (0.63)  |  Apple reports record quarterly revenue, stock jumps 5%
#   negative (0.68)  |  Unemployment remains steady at 3.7%
#   negative (0.80)  |  Some stupid dog ate my shoe.
#   positive (0.92)  |  S&P 500 closes at all-time high on strong earnings season

# %%
headlines = [
    "Future extensions of this work must include real-time pipeline implementation, integration of social media data from platforms such as Reddit is key, expansion to a broader cross-section of assets is a must-have, and a shift toward intraday granularity using tick-level data obligatory. Eventually, everything fails due to the complexity of managing such systems. Most user don't care about the details, they just want to know if the stock is going up or down. The more complex the system, the more points of failure, and the harder it is to maintain. It's a never-ending battle against entropy. FAILURE IS INEVITABLE.",
]

for h in headlines:
    result = finbert(h)
    print(f"{result[0]['label']:>10} ({result[0]['score']:.2f})  |  {h}")
# Out:
#   negative (0.58)  |  Future extensions of this work must include real-time pipeline implementation, integration of social media data from platforms such as Reddit is key, expansion to a broader cross-section of assets is a must-have, and a shift toward intraday granularity using tick-level data obligatory. Eventually, everything fails due to the complexity of managing such systems. Most user don't care about the details, they just want to know if the stock is going up or down. The more complex the system, the more points of failure, and the harder it is to maintain. It's a never-ending battle against entropy. FAILURE IS INEVITABLE.
